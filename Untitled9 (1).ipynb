# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
a=pd.read_csv(r"C:\Users\HP\climate_change_impact_on_agriculture_2024.csv")

# %%
a
# Out:
#       Year    Country              Region  Crop_Type  Average_Temperature_C  \
# 0     2001      India         West Bengal       Corn                   1.55
# 1     2024      China               North       Corn                   3.23
# 2     2001     France       Ile-de-France      Wheat                  21.11
# 3     2001     Canada            Prairies     Coffee                  27.85
# 4     1998      India          Tamil Nadu  Sugarcane                   2.19
# ...    ...        ...                 ...        ...                    ...
# 9995  2022     France  Nouvelle-Aquitaine     Cotton                  30.48
# 9996  1999  Australia          Queensland   Soybeans                   9.53
# 9997  2000  Argentina           Patagonia     Coffee                  31.92
# 9998  1996     Brazil           Southeast   Soybeans                  13.95
# 9999  2015      China               South       Corn                  11.78
#
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         10000 non-null  int64
#  1   Country                      10000 non-null  object
#  2   Region                       10000 non-null  object
#  3   Crop_Type                    10000 non-null  object
#  4   Average_Temperature_C        10000 non-null  float64
#  5   Total_Precipitation_mm       10000 non-null  float64
#  6   CO2_Emissions_MT             10000 non-null  float64
#  7   Crop_Yield_MT_per_HA         10000 non-null  float64
#  8   Extreme_Weather_Events       10000 non-null  int64
#  9   Irrigation_Access_%          10000 non-null  float64
#  10  Pesticide_Use_KG_per_HA      10000 non-null  float64
#  11  Fertilizer_Use_KG_per_HA     10000 non-null  float64
# ...

# %%
a.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of       Year    Country              Region  Crop_Type  Average_Temperature_C  \
# 0     2001      India         West Bengal       Corn                   1.55
# 1     2024      China               North       Corn                   3.23
# 2     2001     France       Ile-de-France      Wheat                  21.11
# 3     2001     Canada            Prairies     Coffee                  27.85
# 4     1998      India          Tamil Nadu  Sugarcane                   2.19
# ...    ...        ...                 ...        ...                    ...
# 9995  2022     France  Nouvelle-Aquitaine     Cotton                  30.48
# 9996  1999  Australia          Queensland   Soybeans                   9.53
# 9997  2000  Argentina           Patagonia     Coffee                  31.92
# 9998  1996     Brazil           Southeast   Soybeans                  13.95
# 9999  2015      China               South       Corn                  11.78
#
# ...

# %%
a.dropna()
# Out:
#       Year    Country              Region  Crop_Type  Average_Temperature_C  \
# 0     2001      India         West Bengal       Corn                   1.55
# 1     2024      China               North       Corn                   3.23
# 2     2001     France       Ile-de-France      Wheat                  21.11
# 3     2001     Canada            Prairies     Coffee                  27.85
# 4     1998      India          Tamil Nadu  Sugarcane                   2.19
# ...    ...        ...                 ...        ...                    ...
# 9995  2022     France  Nouvelle-Aquitaine     Cotton                  30.48
# 9996  1999  Australia          Queensland   Soybeans                   9.53
# 9997  2000  Argentina           Patagonia     Coffee                  31.92
# 9998  1996     Brazil           Southeast   Soybeans                  13.95
# 9999  2015      China               South       Corn                  11.78
#
# ...

# %%
a.head(
# Out:
#    Year Country         Region  Crop_Type  Average_Temperature_C  \
# 0  2001   India    West Bengal       Corn                   1.55
# 1  2024   China          North       Corn                   3.23
# 2  2001  France  Ile-de-France      Wheat                  21.11
# 3  2001  Canada       Prairies     Coffee                  27.85
# 4  1998   India     Tamil Nadu  Sugarcane                   2.19
#
#    Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 0                  447.06             15.22                 1.737
# 1                 2913.57             29.82                 1.737
# 2                 1301.74             25.75                 1.719
# 3                 1154.36             13.91                 3.890
# 4                 1627.48             11.81                 1.080
#
#    Extreme_Weather_Events  Irrigation_Access_%  Pesticide_Use_KG_per_HA  \
# 0                       8                14.54                    10.08
# ...

# %%
average_yields = a.groupby('Crop_Type') ['Crop_Yield_MT_per_HA'].mean()

# %%
b=average_yields

# %%
b
# Out:
# Crop_Type
# Barley        2.285337
# Coffee        2.224206
# Corn          2.223170
# Cotton        2.171580
# Fruits        2.293362
# Rice          2.249131
# Soybeans      2.226682
# Sugarcane     2.263790
# Vegetables    2.201579
# Wheat         2.266631
# Name: Crop_Yield_MT_per_HA, dtype: float64

# %%
pd.DataFrame(b)
# Out:
#             Crop_Yield_MT_per_HA
# Crop_Type
# Barley                  2.285337
# Coffee                  2.224206
# Corn                    2.223170
# Cotton                  2.171580
# Fruits                  2.293362
# Rice                    2.249131
# Soybeans                2.226682
# Sugarcane               2.263790
# Vegetables              2.201579
# Wheat                   2.266631

# %%
plt.figure(figsize=(8,6))
b.plot(kind='pie',shadow=True, autopct='%1.1f%%', startangle=90)
plt.title('Average yield of each variety of crop')
plt.show()

# %% [markdown]
# ### Q2

# %%
a
# Out:
#       Year    Country              Region  Crop_Type  Average_Temperature_C  \
# 0     2001      India         West Bengal       Corn                   1.55
# 1     2024      China               North       Corn                   3.23
# 2     2001     France       Ile-de-France      Wheat                  21.11
# 3     2001     Canada            Prairies     Coffee                  27.85
# 4     1998      India          Tamil Nadu  Sugarcane                   2.19
# ...    ...        ...                 ...        ...                    ...
# 9995  2022     France  Nouvelle-Aquitaine     Cotton                  30.48
# 9996  1999  Australia          Queensland   Soybeans                   9.53
# 9997  2000  Argentina           Patagonia     Coffee                  31.92
# 9998  1996     Brazil           Southeast   Soybeans                  13.95
# 9999  2015      China               South       Corn                  11.78
#
# ...

# %%
q=['Extreme_Weather_Events','Crop_Yield_MT_per_HA']

# %%
q
# Out:
# ['Extreme_Weather_Events', 'Crop_Yield_MT_per_HA']

# %%
numeric=a[q].corr()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(numeric,annot=True,cmap="YlGnBu")
plt.title("Average Total Bill Heatmap by Day and Time")
plt.show()

# %%
aa=['Crop_Yield_MT_per_HA','Fertilizer_Use_KG_per_HA']

# %%
aa
# Out:
# ['Crop_Yield_MT_per_HA', 'Fertilizer_Use_KG_per_HA']

# %%
bb=a[aa].corr()

# %%
bb
# Out:
#                           Crop_Yield_MT_per_HA  Fertilizer_Use_KG_per_HA
# Crop_Yield_MT_per_HA                  1.000000                  0.006423
# Fertilizer_Use_KG_per_HA              0.006423                  1.000000

# %%
sns.jointplot(x='Crop_Yield_MT_per_HA',y='Fertilizer_Use_KG_per_HA',data=bb,kind='kde')
plt.grid(True);
plt.figure(figsize=(10,8))
plt.show()

# %% [markdown]
# ### q4

# %%
a=
