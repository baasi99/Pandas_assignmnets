# %%
import pandas as pd

# %%
pd.read_csv(r"C:\Users\HP\survey_results.csv")
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
data=pd.read_csv(r"C:\Users\HP\survey_results.csv",index_col='Respondent')

# %% [markdown]
# # Q1.Read the dataset and set a particular column as index

# %%
data.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %% [markdown]
# ## Q2Read first 100 devs personal info

# %%
data.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
data.loc[:100,['Age','Gender','Sexuality','Country']]
# Out:
#              Age                                             Gender  \
# Respondent
# 1           14.0                                                Man
# 2           19.0                                                Man
# 3           28.0                                                Man
# 4           22.0                                                Man
# 5           30.0                                                Man
# ...          ...                                                ...
# 96          43.0                                                Man
# 97          25.0  Non-binary, genderqueer, or gender non-conforming
# 98          30.0                                                Man
# 99          21.0                                                Man
# 100         39.0                                              Woman
#
#                           Sexuality                 Country
# Respondent
# 1           Straight / Heterosexual          United Kingdom
# ...

# %% [markdown]
# ## Q3 Set respondent as index columns

# %%
pd.read_csv("C://Users//HP//survey_results.csv",index_col='Respondent')
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %% [markdown]
# ## Q4 Is 1000th developer started his coding at the age of?

# %%
data.loc[1000,'Age1stCode']
# Out:
# '10'

# %% [markdown]
# ## Q5 Most used social media of last developer in the df

# %%
data
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
data.loc[88883,'SocialMedia']
# Out:
# 'Reddit'

# %% [markdown]
# ## Q6 100 to 200 devs Salary and are they satisfied in their job?

# %%
data.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
data.loc[100:200,['CompTotal','JobSat']]
# Out:
#             CompTotal                              JobSat
# Respondent
# 100          300000.0                      Very satisfied
# 101               NaN                  Slightly satisfied
# 102           67800.0                  Slightly satisfied
# 103               NaN                                 NaN
# 104          155000.0                   Very dissatisfied
# ...               ...                                 ...
# 196           39000.0                   Very dissatisfied
# 197           86000.0               Slightly dissatisfied
# 198               NaN                      Very satisfied
# 199               NaN                                 NaN
# 200               NaN  Neither satisfied nor dissatisfied
#
# [100 rows x 2 columns]

# %% [markdown]
# ## Q7. 400 to 300 devs Job satisfaction level and what are the challanges are they facing in their working place?

# %%
data.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
data.loc[300:400,['JobSat','WorkChallenge']]
# Out:
#                                         JobSat  \
# Respondent
# 300                                        NaN
# 301                         Slightly satisfied
# 302         Neither satisfied nor dissatisfied
# 303                      Slightly dissatisfied
# 304                             Very satisfied
# ...                                        ...
# 396                             Very satisfied
# 397                                        NaN
# 398                             Very satisfied
# 399                      Slightly dissatisfied
# 400                             Very satisfied
#
#                                                 WorkChallenge
# Respondent
# 300                                                       NaN
# 301         Distracting work environment;Not enough people...
# 302         Inadequate access to necessary tools;Lack of s...
# 303                     Distracting work environment;Meetings
# ...

# %% [markdown]
# ## Q8 how long devs 100,200,300 works in a week (by hours)?

# %%
data.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
data.loc[[100,200,300],['WorkWeekHrs']]
# Out:
#             WorkWeekHrs
# Respondent
# 100                35.0
# 200                35.0
# 300                 NaN

# %% [markdown]
# ## Q9 Salary of last 100 devs and their years of coding experience

# %%
data.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
data.loc[88883:,'YearsCode']
# Out:
# Respondent
# 88883                   9
# 138      Less than 1 year
# 549                     2
# 905                     8
# 1248                   25
#                ...
# 88377                 NaN
# 88601                 NaN
# 88802                 NaN
# 88816                 NaN
# 88863                   8
# Name: YearsCode, Length: 553, dtype: object

# %% [markdown]
# ## Q10.How many Male and Female Devs are there in the last 100 devs

# %%
data.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
data.loc[88883:,'Gender'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of Respondent
# 88883    Man
# 138      Man
# 549      Man
# 905      Man
# 1248     Man
#         ...
# 88377    Man
# 88601    NaN
# 88802    NaN
# 88816    NaN
# 88863    Man
# Name: Gender, Length: 553, dtype: object>

# %% [markdown]
# ## Q11 How many devs are there from India in the first 200 devs list?

# %%
data.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
data.loc[:200,'Country'].value_counts()
# Out:
# Country
# United States             46
# India                     20
# United Kingdom            11
# Germany                   11
# Canada                     9
# Australia                  6
# Netherlands                5
# Spain                      5
# Russian Federation         5
# South Africa               4
# Austria                    4
# Italy                      4
# Argentina                  4
# Poland                     4
# New Zealand                4
# Brazil                     3
# France                     3
# Sweden                     2
# Bosnia and Herzegovina     2
# Croatia                    2
# Estonia                    2
# Pakistan                   2
# Ukraine                    2
# China                      2
# Greece                     2
# Bangladesh                 2
# Malaysia                   2
# Czech Republic             2
# Sri Lanka                  2
# Turkey                     2
# Switzerland                2
# ...

# %%
#The answer is 20

# %% [markdown]
# ## Q12 Developers whose agest 1st coded and current age from 4000 to 4500

# %%
data.loc[4000:4500,['Age','Age1stCode']]
# Out:
#              Age Age1stCode
# Respondent
# 4000        25.0         11
# 4001        28.0         14
# 4002        33.0         16
# 4003        17.0         10
# 4004        26.0         14
# ...          ...        ...
# 4496        18.0         15
# 4497        38.0         11
# 4498        27.0         20
# 4499        15.0         14
# 4500         NaN         20
#
# [496 rows x 2 columns]

# %% [markdown]
# ## Q13 Salary of 10000 to 11000 and are they have any dependents?

# %%
data.loc[10000:11000,'Dependents']
# Out:
# Respondent
# 10000     No
# 10001    Yes
# 10002    Yes
# 10003     No
# 10004     No
#         ...
# 10996    Yes
# 10997     No
# 10998    NaN
# 10999    Yes
# 11000     No
# Name: Dependents, Length: 994, dtype: object

# %% [markdown]
# ## Q14 salary of the developer 54 is really far from the salary of the 78th developer?

# %%
data.loc[[54,78],'CompTotal']
# Out:
# Respondent
# 54     51500.0
# 78    550000.0
# Name: CompTotal, dtype: float64

# %% [markdown]
# ## Q15 How many unique Ethnicity are there in the devs community?

# %%
data['Ethnicity'].unique()
# Out:
# array([nan, 'White or of European descent',
#        'White or of European descent;Multiracial', 'East Asian',
#        'Black or of African descent;East Asian;Hispanic or Latino/Latina;Middle Eastern;Native American, Pacific Islander, or Indigenous Australian;South Asian;White or of European descent;Biracial;Multiracial',
#        'Black or of African descent',
#        'Hispanic or Latino/Latina;Multiracial',
#        'Hispanic or Latino/Latina', 'Middle Eastern', 'South Asian',
#        'Multiracial', 'East Asian;South Asian', 'Biracial',
#        'Native American, Pacific Islander, or Indigenous Australian;White or of European descent',
#        'East Asian;Biracial;Multiracial',
#        'Black or of African descent;White or of European descent;Biracial',
#        'Middle Eastern;White or of European descent',
#        'Native American, Pacific Islander, or Indigenous Australian',
#        'Black or of African descent;White or of European descent',
# ...
